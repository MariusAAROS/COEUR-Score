# %% [markdown]
# # Libraries

# %%
from experiments.noise_based.plot_incremental_noise import load_results_multi_seed, plot_noise_vs_scores_multi_seed, \
                                                    compute_corrs_multi_seed, plot_corrs_multi_seed, \
                                                    save_results, split_coeur_results

# %%
import os
experiment_path = "experiments/noise_based"

# %% [markdown]
# # I. Advanced Observation (Retro)

# %% [markdown]
# ## 1. Epic Noise Experiment

# %%
retro_mul_res_epic = load_results_multi_seed(
    main_folder_path=os.path.join(experiment_path, "output", "retro"),
    experiment_type="epic/set_9_paper_results"
    )

# %%
plot_noise_vs_scores_multi_seed(retro_mul_res_epic, y="bwise_coverage", noise_ref_level="epic",
                                 metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(retro_mul_res_epic, y="ewise_coverage", noise_ref_level="epic",
                                 metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(retro_mul_res_epic, y="swise_coverage", noise_ref_level="epic",
                                 metrics_to_plot=None)

# %%
plot_noise_vs_scores_multi_seed(retro_mul_res_epic, y="model_wise_coherence", model_name="KMeans", 
                                noise_ref_level="epic", metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(retro_mul_res_epic, y="model_wise_coherence", 
                                model_name="AgglomerativeClustering", 
                                noise_ref_level="epic", metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(retro_mul_res_epic, y="model_wise_coherence", 
                                model_name="SpectralClustering", 
                                noise_ref_level="epic", metrics_to_plot=None)

# %% [markdown]
# ## 2. Story Noise Experiment

# %%
retro_mul_res_story = load_results_multi_seed(
    main_folder_path=os.path.join(experiment_path, "output", "retro"),
    experiment_type="story/set_9_paper_results"
    )

# %%
plot_noise_vs_scores_multi_seed(retro_mul_res_story, y="bwise_coverage", noise_ref_level="story",
                                 metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(retro_mul_res_story, y="ewise_coverage", noise_ref_level="story",
                                 metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(retro_mul_res_story, y="swise_coverage", noise_ref_level="story",
                                 metrics_to_plot=None)

# %%
plot_noise_vs_scores_multi_seed(retro_mul_res_story, y="model_wise_coherence",
                                model_name="KMeans",
                                noise_ref_level="story",
                                metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(retro_mul_res_story, y="model_wise_coherence",
                                model_name="AgglomerativeClustering",
                                noise_ref_level="story",
                                metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(retro_mul_res_story, y="model_wise_coherence",
                                model_name="SpectralClustering",
                                noise_ref_level="story",
                                metrics_to_plot=None)

# %% [markdown]
# # II. Advanced Observation (Trident)

# %% [markdown]
# ## 1. Epic Noise Experiment

# %%
trident_mul_res_epic = load_results_multi_seed(
    main_folder_path=os.path.join(experiment_path, "output", "trident"),
    experiment_type="epic/set_9_paper_results"
)

# %%
plot_noise_vs_scores_multi_seed(trident_mul_res_epic, y="bwise_coverage", noise_ref_level="epic",
                                 metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(trident_mul_res_epic, y="ewise_coverage", noise_ref_level="epic")
plot_noise_vs_scores_multi_seed(trident_mul_res_epic, y="swise_coverage", noise_ref_level="epic")

# %%
plot_noise_vs_scores_multi_seed(trident_mul_res_epic, y="model_wise_coherence", model_name="KMeans", noise_ref_level="epic")
plot_noise_vs_scores_multi_seed(trident_mul_res_epic, y="model_wise_coherence", model_name="AgglomerativeClustering", noise_ref_level="epic")
plot_noise_vs_scores_multi_seed(trident_mul_res_epic, y="model_wise_coherence", model_name="SpectralClustering", noise_ref_level="epic")

# %% [markdown]
# ## 2. Story Noise Experiment

# %%
trident_mul_res_story = load_results_multi_seed(
    main_folder_path=os.path.join(experiment_path, "output", "trident"),
    experiment_type="story/set_9_paper_results"
)

# %%
plot_noise_vs_scores_multi_seed(trident_mul_res_story, y="bwise_coverage", noise_ref_level="story",
                                 metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(trident_mul_res_story, y="ewise_coverage", noise_ref_level="story",
                                 metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(trident_mul_res_story, y="swise_coverage", noise_ref_level="story",
                                 metrics_to_plot=None)

# %%
plot_noise_vs_scores_multi_seed(trident_mul_res_story, y="model_wise_coherence", noise_ref_level="story",
                                 model_name="KMeans", metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(trident_mul_res_story, y="model_wise_coherence", noise_ref_level="story",
                                 model_name="AgglomerativeClustering", metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(trident_mul_res_story, y="model_wise_coherence", noise_ref_level="story",
                                 model_name="SpectralClustering", metrics_to_plot=None)

# %% [markdown]
# # III. Advanced Observation (Alfred)

# %% [markdown]
# ## 1. Epic Noise Experiment

# %%
alfred_mul_res_epic = load_results_multi_seed(
    main_folder_path=os.path.join(experiment_path, "output", "alfred"),
    experiment_type="epic/set_9_paper_results"
    )

# %%
plot_noise_vs_scores_multi_seed(alfred_mul_res_epic, y="bwise_coverage", noise_ref_level="epic",
                                 metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(alfred_mul_res_epic, y="ewise_coverage", noise_ref_level="epic",
                                 metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(alfred_mul_res_epic, y="swise_coverage", noise_ref_level="epic",
                                 metrics_to_plot=None)

# %%
plot_noise_vs_scores_multi_seed(alfred_mul_res_epic, y="model_wise_coherence",
                                model_name="KMeans",
                                noise_ref_level="epic",
                                metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(alfred_mul_res_epic, y="model_wise_coherence",
                                model_name="AgglomerativeClustering",
                                noise_ref_level="epic",
                                metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(alfred_mul_res_epic, y="model_wise_coherence",
                                model_name="SpectralClustering",
                                noise_ref_level="epic",
                                metrics_to_plot=None)

# %% [markdown]
# ## 2. Story Noise Experiment

# %%
alfred_mul_res_story = load_results_multi_seed(
    main_folder_path=os.path.join(experiment_path, "output", "alfred"),
    experiment_type="story/set_9_paper_results"
    )

# %%
plot_noise_vs_scores_multi_seed(alfred_mul_res_story, y="bwise_coverage", noise_ref_level="story",
                                 metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(alfred_mul_res_story, y="ewise_coverage", noise_ref_level="story",
                                 metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(alfred_mul_res_story, y="swise_coverage", noise_ref_level="story",
                                 metrics_to_plot=None)

# %%
plot_noise_vs_scores_multi_seed(alfred_mul_res_story, y="model_wise_coherence",
                                model_name="KMeans",
                                noise_ref_level="story",
                                metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(alfred_mul_res_story, y="model_wise_coherence",
                                model_name="AgglomerativeClustering",
                                noise_ref_level="story",
                                metrics_to_plot=None)
plot_noise_vs_scores_multi_seed(alfred_mul_res_story, y="model_wise_coherence",
                                model_name="SpectralClustering",
                                noise_ref_level="story",
                                metrics_to_plot=None)
